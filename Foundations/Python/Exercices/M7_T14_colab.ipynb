# %% [markdown]
# <a href="https://colab.research.google.com/github/raulmabcn/DataAnalyst/blob/main/Foundations/Python/Exercices/M7_T14_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## T14
# La nostra empresa está colaborant amb el colectiu de metges per veure quina càrrega de treball están patint.
# La idea es veure quins metges han de donar suport a més pacients i quins sembla que tenen menys persones a càrrec.
# Per fer-ho, ens han proporcionat un conjunt de dades (hospitals.csv)
# que conté informació detallada sobre els hospitals del país.
#
# Crea una funció en Python que rebi com a paràmetres:
# * Un DataFrame amb dades d’hospitals.
# * El nombre n d’hospitals que es volen obtenir com a resultat.
#
# La funció ha de calcular, per a cada hospital la càrrega de treball dels metges, utilitzant la següent fórmula:
#
# `càrrega treball metge = num_llits /num_metges * percentatge ocupació`
#
# La funció ha de retornar els n hospitals amb més càrrega de treball per metge.
# Executa la funció per obtenir 10 hospitals i després per obtenir-ne 20.

# %%
import pandas as pd
from pathlib import Path
from tabulate import tabulate

# %%
def load_data_file():

    path_cwd =  str(Path.cwd())

    msg_file = f"Ruta del fichero de datos desde {Path.cwd()}: "

    file = input( msg_file )

    path_file = Path(file)

    while not path_file.exists() :
        print( "Fichero no existe, por favor, verifica la ruta y el nombre del fichero: " )
        file = input( msg_file )
        path_file = Path(file)

    file_path = path_file.resolve()

    return pd.read_csv( file_path , sep = ";", encoding = "latin-1")

# %%
def request_n_hospitals( t_hospitals ):

    n_hospitals = 10

    msg = f"Introduzca cuantos hospitales entre los {t_hospitals} se mostraran en el resultado, por defecto {n_hospitals}: "

    n_user_hospitals = input( msg )

    while n_user_hospitals != '' and not n_user_hospitals.isdigit() or int(n_user_hospitals) < 1:
        print("Introduzca un número entero mayor a 0 o presione enter para obtener el número por defecto")
        n_user_hospitals = input( msg )

    n_hospitals = n_hospitals if ( n_user_hospitals == '' ) else int( n_user_hospitals )

    return n_hospitals

# %%
def do_hospitals_analisys( df, n_hospitals ):

    df["carga_trabajo_medico"] = df["num_camas"] / df["num_medicos"] * df["porcentaje_ocupacion"]

    #return df.sort_values("carga_trabajo_medico", ascending = False).head( n_hospitals )

    #df['rank'] = df['carga_trabajo_medico'].rank(method='first', ascending=False)
    #return df[df['rank'] <= n_hospitals].sort_values('rank')

    return df.nlargest(n_hospitals, "carga_trabajo_medico")

# %%
def print_analisys( analisys):

    print(tabulate(analisys, headers='keys', tablefmt='psql'))

    return None

# %% [markdown]
# Main process

# %%
df          = load_data_file()
#n_hospitals = request_n_hospitals( df["hospital_id"].count() )

n_hospitals = 10
analisys    = do_hospitals_analisys( df, n_hospitals )

print_analisys( analisys )

n_hospitals = 20
analisys    = do_hospitals_analisys( df, n_hospitals )

print_analisys( analisys )
# Out:
# Ruta del fichero de datos desde /content: hospitals.csv
# +-----+---------------+-------------------------------------------+----------------------+-------------+----------------------+------------------------------+-------------+---------------+-----------------------+------------------------+------------------------+
# |     |   hospital_id | nombre                                    | localidad            | provincia   | comunidad_autonoma   |   presupuesto_anual_millones |   num_camas |   num_medicos |   indice_satisfaccion |   porcentaje_ocupacion |   carga_trabajo_medico |
# |-----+---------------+-------------------------------------------+----------------------+-------------+----------------------+------------------------------+-------------+---------------+-----------------------+------------------------+------------------------|
# |  66 |            67 | Hospital de Sierrallana                   | Torrelavega          | Cantabria   | Cantabria            |                       151.59 |         996 |            15 |                   4.6 |                   85.5 |                5677.2  |
# |  57 |            58 | Hospital Doctor Jose Molina Orosa         | Arrecife (Lanzarote) | Las Palmas  | Islas Canarias       |                       364.42 |         532 |            14 |                   9   |                   86.3 |                3279.4  |
# |  14 |            15 | Hospital Universitario Virgen del Rocio   | Sevilla              | Sevilla     | Andalucia            |                       413.7  |         507 |            19 |                   6.2 |                   97.9 |                2612.38 |
# |   2 |             3 | Hospital Universitario Puerta del Mar     | Cadiz                | Cadiz       | Andalucia            |                       496.8  |         834 |            32 |                   6.4 |                   81.5 |                2124.09 |
# | 104 |           105 | Hospital de Tortosa Verge de la Cinta     | Tortosa              | Tarragona   | Cataluña             |                       317.36 |         919 |            48 |                   6.4 |                   96.4 |                1845.66 |
# |  15 |            16 | Hospital Universitario Virgen Macarena    | Sevilla              | Sevilla     | Andalucia            |                       386.07 |         552 |            30 |                   3.1 |                   89.2 |                1641.28 |
# |  50 |            51 | Hospital Mateu Orfila                     | Mao                  | Menorca     | Islas Baleares       |                        66.04 |         849 |            38 |                   8.2 |                   70.6 |                1577.35 |
# |   5 |             6 | Hospital Infanta Margarita                | Cordoba              | Cordoba     | Andalucia            |                        25.65 |         456 |            36 |                   3   |                   99.7 |                1262.87 |
# |  99 |           100 | Hospital d'Olot i Comarcal de la Garrotxa | Olot                 | Girona      | Cataluña             |                       387.58 |         305 |            25 |                   1.5 |                   90.3 |                1101.66 |
# |  77 |            78 | Hospital General Nuestra Señora del Prado | Talavera de la Reina | Toledo      | Castilla-La Mancha   |                       289.9  |         715 |            50 |                   7.2 |                   67.2 |                 960.96 |
# +-----+---------------+-------------------------------------------+----------------------+-------------+----------------------+------------------------------+-------------+---------------+-----------------------+------------------------+------------------------+
# +-----+---------------+----------------------------------------------+----------------------+-------------+----------------------+------------------------------+-------------+---------------+-----------------------+------------------------+------------------------+
# |     |   hospital_id | nombre                                       | localidad            | provincia   | comunidad_autonoma   |   presupuesto_anual_millones |   num_camas |   num_medicos |   indice_satisfaccion |   porcentaje_ocupacion |   carga_trabajo_medico |
# |-----+---------------+----------------------------------------------+----------------------+-------------+----------------------+------------------------------+-------------+---------------+-----------------------+------------------------+------------------------|
# |  66 |            67 | Hospital de Sierrallana                      | Torrelavega          | Cantabria   | Cantabria            |                       151.59 |         996 |            15 |                   4.6 |                   85.5 |               5677.2   |
# |  57 |            58 | Hospital Doctor Jose Molina Orosa            | Arrecife (Lanzarote) | Las Palmas  | Islas Canarias       |                       364.42 |         532 |            14 |                   9   |                   86.3 |               3279.4   |
# |  14 |            15 | Hospital Universitario Virgen del Rocio      | Sevilla              | Sevilla     | Andalucia            |                       413.7  |         507 |            19 |                   6.2 |                   97.9 |               2612.38  |
# |   2 |             3 | Hospital Universitario Puerta del Mar        | Cadiz                | Cadiz       | Andalucia            |                       496.8  |         834 |            32 |                   6.4 |                   81.5 |               2124.09  |
# | 104 |           105 | Hospital de Tortosa Verge de la Cinta        | Tortosa              | Tarragona   | Cataluña             |                       317.36 |         919 |            48 |                   6.4 |                   96.4 |               1845.66  |
# |  15 |            16 | Hospital Universitario Virgen Macarena       | Sevilla              | Sevilla     | Andalucia            |                       386.07 |         552 |            30 |                   3.1 |                   89.2 |               1641.28  |
# |  50 |            51 | Hospital Mateu Orfila                        | Mao                  | Menorca     | Islas Baleares       |                        66.04 |         849 |            38 |                   8.2 |                   70.6 |               1577.35  |
# |   5 |             6 | Hospital Infanta Margarita                   | Cordoba              | Cordoba     | Andalucia            |                        25.65 |         456 |            36 |                   3   |                   99.7 |               1262.87  |
# |  99 |           100 | Hospital d'Olot i Comarcal de la Garrotxa    | Olot                 | Girona      | Cataluña             |                       387.58 |         305 |            25 |                   1.5 |                   90.3 |               1101.66  |
# |  77 |            78 | Hospital General Nuestra Señora del Prado    | Talavera de la Reina | Toledo      | Castilla-La Mancha   |                       289.9  |         715 |            50 |                   7.2 |                   67.2 |                960.96  |
# | 165 |           166 | Hospital San Pedro                           | Logroño              | La Rioja    | La Rioja             |                       457.88 |         944 |           104 |                   3.4 |                   89.4 |                811.477 |
# |  87 |            88 | Complejo Asistencial de Zamora               | Zamora               | Zamora      | Castilla y Leon      |                       204.16 |         967 |           126 |                   6.7 |                   92.5 |                709.901 |
# |   3 |             4 | Hospital de Jerez                            | Jerez de la Frontera | Cadiz       | Andalucia            |                       149.66 |         773 |            56 |                   5.8 |                   50.7 |                699.841 |
# | 130 |           131 | Hospital da Costa                            | Burela               | Lugo        | Galicia              |                       133.73 |         430 |            49 |                   8.4 |                   69.2 |                607.265 |
# |  64 |            65 | Hospital Universitario Marques de Valdecilla | Santander            | Cantabria   | Cantabria            |                       419.6  |         530 |            85 |                   3.9 |                   93.3 |                581.753 |
# |  26 |            27 | Hospital de Antequera                        | Antequera            | Malaga      | Andalucia            |                       220.57 |         521 |            81 |                   5   |                   89.3 |                574.386 |
# | 162 |           163 | Hospital de Santa Marina                     | Bilbao               | Vizcaya     | Pais Vasco           |                       204.24 |         936 |           149 |                   8.7 |                   85.9 |                539.613 |
# |  74 |            75 | Hospital de Puerto Llano                     | Puerto Llano         | Ciudad Real | Castilla-La Mancha   |                       450    |         553 |            85 |                   2.9 |                   80.7 |                525.025 |
# | 121 |           122 | Hospital de Zafra                            | Zafra                | Badajoz     | Extremadura          |                       442.78 |         624 |           119 |                   5.4 |                   98.8 |                518.077 |
# |  10 |            11 | Hospital Universitario de Jaen               | Jaen                 | Jaen        | Andalucia            |                       339.76 |         842 |           158 |                   7   |                   91.2 |                486.015 |
# +-----+---------------+----------------------------------------------+----------------------+-------------+----------------------+------------------------------+-------------+---------------+-----------------------+------------------------+------------------------+
