# %% [markdown]
# <a href="https://colab.research.google.com/github/raulmabcn/DataAnalyst/blob/main/Foundations/Python/Exercices/practica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'hospital_id': [1,2,3,4,5],
    'num_camas': [100,120,110,np.nan,140],
    'indice_satisfaccion': [7.5, 8.0, np.nan, 7.0, 8.5]
})

# %%
print("--- Mean ---")
print("Pandas mean:", df['indice_satisfaccion'].mean())
print("Numpy mean:", np.mean(df['indice_satisfaccion']))
print("Numpy nanmean:", np.nanmean(df['indice_satisfaccion']))

print("--- Sum ---")
print("Pandas var:", df['num_camas'].sum())
print("Numpy var:", np.sum(df['num_camas']))

print("--- Max ---")
print("Pandas var:", df['num_camas'].max())
print("Numpy var:", np.max(df['num_camas']))

print("--- Min ---")
print("Pandas var:", df['num_camas'].min())
print("Numpy var:", np.min(df['num_camas']))

print("--- Prod ---")
print("Pandas var:", df['num_camas'].prod())
print("Numpy var:", np.prod(df['num_camas']))

print("--- Size ---")
print("Pandas var:", df['num_camas'].size)
print("Numpy var:", np.size(df['num_camas']))

print("--- Quantile/Percentile ---")
print("Pandas var:", df['indice_satisfaccion'].quantile(0.25))
print("Numpy var:", np.percentile(df['indice_satisfaccion'],25))

print("--- Std ---")
print("Pandas var:", df['num_camas'].std())
print("Numpy var:", np.std(df['num_camas']))
print("Numpy var ddof=1:", np.std(df['num_camas'], ddof=1))

print("--- Median ---")
print("Pandas var:", df['num_camas'].median())
print("Numpy var:", np.median(df['num_camas']))

print("--- Var ---")
print("Pandas var:", df['num_camas'].var())
print("Numpy var:", np.var(df['num_camas']))
print("Numpy var ddof=1:", np.var(df['num_camas'], ddof=1))
# Out:
# --- Mean ---
# Pandas mean: 7.75
# Numpy mean: 7.75
# Numpy nanmean: 7.75
# --- Sum ---
# Pandas var: 470.0
# Numpy var: 470.0
# --- Max ---
# Pandas var: 140.0
# Numpy var: 140.0
# --- Min ---
# Pandas var: 100.0
# Numpy var: 100.0
# --- Prod ---
# Pandas var: 184800000.0
# Numpy var: 184800000.0
# --- Size ---
# Pandas var: 5
# Numpy var: 5
# --- Quantile/Percentile ---
# Pandas var: 7.375
# Numpy var: nan
# --- Std ---
# Pandas var: 17.07825127659933
# Numpy var: 14.79019945774904
# Numpy var ddof=1: 17.07825127659933
# --- Median ---
# Pandas var: 115.0
# Numpy var: nan
# --- Var ---
# Pandas var: 291.6666666666667
# Numpy var: 218.75
# Numpy var ddof=1: 291.6666666666667

# %%
# Check if a string is decimal: str.isdecimal()
# Check if a string is digits: str.isdigit()
# Check if a string is numeric: str.isnumeric()
# Check if a string is alphabetic: str.isalpha()
# Check if a string is alphanumeric: str.isalnum()
# Check if a string is ASCII: str.isascii()

data = [1, 2, -3, -4]
for idx, num in enumerate(data):
    if num < 0: data[idx] = 0

squares = [i*i for i in range(10)]

data = [{"name": "Max", "age": 6},
        {"name": "Lisa", "age": 20},
        {"name": "Ben", "age": 9}
        ]

sorted_data = sorted(data, key=lambda x: x["age"], reverse=True)

import sys

my_list = [i for i in range(10000)]
#print(sys.getsizeof(my_list), 'bytes') # 87616 bytes

my_gen = (i for i in range(10000))
#print(sys.getsizeof(my_gen), 'bytes') # 128 bytes

my_dict = {'item': 'football', 'price': 10.00}
#count = my_dict['count'] # KeyError!

# better:

count = my_dict.get('count', 0) # optional default value
print( my_dict )

count = my_dict.setdefault('count', 0)

print(my_dict) # 0


d1 = {'name': 'Alex', 'age': 25}
d2 = {'name': 'Alex', 'city': 'New York'}
merged_dict = {**d1, **d2}
print(merged_dict) # {'name': 'Alex', 'age': 25, 'city': 'New York'}


list_1 = [1, 3, 5, 7, 8]
list_2 = [1, 2, 3, 4, 5, 6, 7, 8, 9]

diferencia          = list(set(list_2) - set(list_1))
union               = list(set(list_1) | set(list_2))
uno_u_otro_no_ambos = list(set(list_1) ^ set(list_2))
interseccion        = list(set(list_1) & set(list_2))
subconjunto         = set(list_1).issubset(set(list_2))
superconjunto       = set(list_1).issuperset(set(list_2))
nocomparten         = set(list_1).isdisjoint(set(list_2))

set(list_1).add(10)
set(list_1).remove(8)   # error si no existe
set(list_1).discard(4)  # no da error
set(list_1).pop()
set(list_1).clear()
# Out:
# {'item': 'football', 'price': 10.0}
# {'item': 'football', 'price': 10.0, 'count': 0}
# {'name': 'Alex', 'age': 25, 'city': 'New York'}
# False
