# %% [markdown]
# <a href="https://colab.research.google.com/github/raulmabcn/DataAnalyst/blob/main/Foundations/Python/Exercices/M7_T13_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## MT7_T13
# La nostra empresa es dedica a realitzar anàlisis de dades hospitalaries,
# i un client ens ha sol·licitat una eina per identificar dades bàsiques dels hospitals
# de cada comunitat autònoma de forma automàtica.
#
# Per això, cal crear una funció que rebi dos paràmetres:
#
#     * Un DataFrame amb informació d’hospitals (com el del fitxer hospitals.csv).
#     * El nom d’una comunitat autònoma (com a cadena de text).
#
# La funció ha de retornar un diccionari amb les següents dades relacionades amb la comunitat autónoma indicada:
#
#     * Quantitat d’hospitals que hi ha a la comunitat autònoma
#     * Quantitat d’hospitals que hi ha a la comunitat autónoma que tenen més del 50% d’ocupació
#     * Indice_satifaccion màxim de la comunitat autónoma
#     * Indice_satifaccion mínim de la comunitat autònoma
#     * Total de llits a la comunitat autónoma
#     * Mitjana de l’index de satisfacció dels hospitals de la comunitat autònoma
#
# Finalment, carrega el fitxer adjunt amb aquesta instrucció:
#
# ```
# data = pd.read_csv("arxiu csv", sep = ";", encoding = "latin-1")
# ```
# i executa la funció per a diverses comunitats autònomes i mostra els resultats obtinguts.

# %%
import pandas as pd
from pathlib import Path

# %%
def count_hospitals(df_comunity):
    return int( df_comunity["hospital_id"].count() )

def count_hospitals_with_ocupation(df_comunity, ocupation = 50):
    return int( df_comunity[ df_comunity["porcentaje_ocupacion"] > ocupation ]["hospital_id"].count() )

def get_max_satisfaction_index(df_comunity):
    return float( df_comunity["indice_satisfaccion"].max() )

def get_min_satisfaction_index(df_comunity):
    return float( df_comunity["indice_satisfaccion"].min() )

def get_mean_satisfaction_index(df_comunity, n_decimals = 1):
    return round( float( df_comunity["indice_satisfaccion"].mean() ), n_decimals )

def get_total_beds(df_comunity):
    return int( df_comunity["num_camas"].sum() )

def filter_df_by_comunity(df, comunity):
    return df[ df["comunidad_autonoma"] == comunity ]

# %%
def launch_comunity_analisys( df, comunity ):

    analisys = {}
    df_comunity = filter_df_by_comunity( df, comunity )

    analisys['n_hospitals']               = count_hospitals(df_comunity)
    analisys['n_hospitals_50%_occup']     = count_hospitals_with_ocupation(df_comunity)
    analisys['max_satisf_index']          = get_max_satisfaction_index(df_comunity)
    analisys['min_satisf_index']          = get_min_satisfaction_index(df_comunity)
    analisys['total_beds']                = get_total_beds(df_comunity)
    analisys['mean_satisf_index']         = get_mean_satisfaction_index(df_comunity)

    return analisys

def print_analisys( analisys, comunity ):

    print( comunity.center(80,'_') + "\n" )
    for key,value in analisys.items():
        print(f"{key.ljust(25)} = {value}")
    print( "".center(80,'_') + "\n" )

# %%
def load_data_file():

    # Fixed path for testing
    #file = ".\\Samples\\hospitals.csv"
    file = input( "Ruta del fichero de datos desde " + str(Path.cwd()) +": " )

    p = Path(file)

    while not p.exists() :
        print( "Fichero no existe, por favor, verifica la ruta y el nombre del fichero: " )
        file = input( "Ruta del fichero de datos desde " + str(Path.cwd()) +": " )
        p = Path(file)

    file_path = p.resolve()

    return pd.read_csv( file_path , sep = ";", encoding = "latin-1")

# %%
def print_comunities( comunities):
    print( "Lista de comunidades disponibles para analizar:")


    for indice,community in  enumerate(comunities, start = 0):
      if indice % 2 == 0:
        print( community.center(60, ' '), end=' ')
      else:
        print( community.center(60, ' ') )

# %%
def process_data_frame( df ):

    comunities = df["comunidad_autonoma"].unique()

    print_comunities( comunities )

    comunity = input( "Si quiere analizar una comunidad en concreto introduzca su nombre, para analizar todas, pulse enter: " )

    if comunity == '':
        for c in comunities:
            print_analisys( launch_comunity_analisys( df, c ), c )

    else:
        print_analisys(launch_comunity_analisys( df, comunity ), comunity)

# %% [markdown]
# Main Process:

# %%
df = load_data_file()
process_data_frame(df)
# Out:
# Ruta del fichero de datos desde /content: hospitals.csv
# Lista de comunidades disponibles para analizar:
#                          Andalucia                                                      Aragon
#                           Asturias                                                  Islas Baleares
#                        Islas Canarias                                                 Cantabria
#                      Castilla-La Mancha                                            Castilla y Leon
#                           Cataluña                                               Comunidad Valenciana
#                         Extremadura                                                    Galicia
#                     Comunidad de Madrid                                            Region de Murcia
#                           Navarra                                                     Pais Vasco
#                           La Rioja                                                      Ceuta
#                           Melilla                            Si quiere analizar una comunidad en concreto introduzca su nombre, para analizar todas, pulse enter:
# ___________________________________Andalucia____________________________________
#
# n_hospitals          = 31
# n_hospitals_50%_occup = 31
# max_satisf_index     = 9.8
# min_satisf_index     = 1.6
# total_beds           = 16201
# mean_satisf_index    = 5.5
# ________________________________________________________________________________
#
# _____________________________________Aragon_____________________________________
#
# n_hospitals          = 10
# n_hospitals_50%_occup = 10
# max_satisf_index     = 9.2
# min_satisf_index     = 4.7
# total_beds           = 4661
# mean_satisf_index    = 6.9
# ________________________________________________________________________________
#
# ____________________________________Asturias____________________________________
#
# n_hospitals          = 6
# n_hospitals_50%_occup = 6
# max_satisf_index     = 9.7
# min_satisf_index     = 2.0
# total_beds           = 1980
# mean_satisf_index    = 7.4
# ________________________________________________________________________________
#
# _________________________________Islas Baleares_________________________________
#
# n_hospitals          = 7
# n_hospitals_50%_occup = 7
# max_satisf_index     = 8.2
# min_satisf_index     = 1.3
# total_beds           = 3947
# mean_satisf_index    = 5.3
# ________________________________________________________________________________
#
# _________________________________Islas Canarias_________________________________
#
# n_hospitals          = 9
# n_hospitals_50%_occup = 9
# max_satisf_index     = 9.2
# min_satisf_index     = 3.9
# total_beds           = 4858
# mean_satisf_index    = 7.1
# ________________________________________________________________________________
#
# ___________________________________Cantabria____________________________________
#
# n_hospitals          = 4
# n_hospitals_50%_occup = 4
# max_satisf_index     = 7.2
# min_satisf_index     = 2.6
# total_beds           = 3166
# mean_satisf_index    = 4.6
# ________________________________________________________________________________
#
# _______________________________Castilla-La Mancha_______________________________
#
# n_hospitals          = 11
# n_hospitals_50%_occup = 11
# max_satisf_index     = 9.3
# min_satisf_index     = 1.2
# total_beds           = 4958
# mean_satisf_index    = 5.3
# ________________________________________________________________________________
#
# ________________________________Castilla y Leon_________________________________
#
# n_hospitals          = 11
# n_hospitals_50%_occup = 11
# max_satisf_index     = 9.3
# min_satisf_index     = 2.3
# total_beds           = 5948
# mean_satisf_index    = 6.1
# ________________________________________________________________________________
#
# ____________________________________Cataluña____________________________________
#
# n_hospitals          = 16
# n_hospitals_50%_occup = 16
# max_satisf_index     = 7.3
# min_satisf_index     = 1.1
# total_beds           = 8955
# mean_satisf_index    = 4.9
# ________________________________________________________________________________
#
# ______________________________Comunidad Valenciana______________________________
#
# n_hospitals          = 12
# n_hospitals_50%_occup = 12
# max_satisf_index     = 9.9
# min_satisf_index     = 3.3
# total_beds           = 6547
# mean_satisf_index    = 6.3
# ________________________________________________________________________________
#
# __________________________________Extremadura___________________________________
#
# n_hospitals          = 7
# n_hospitals_50%_occup = 7
# max_satisf_index     = 7.9
# min_satisf_index     = 1.2
# total_beds           = 2805
# mean_satisf_index    = 4.5
# ________________________________________________________________________________
#
# ____________________________________Galicia_____________________________________
#
# n_hospitals          = 11
# n_hospitals_50%_occup = 11
# max_satisf_index     = 8.4
# min_satisf_index     = 1.2
# total_beds           = 6164
# mean_satisf_index    = 5.8
# ________________________________________________________________________________
#
# ______________________________Comunidad de Madrid_______________________________
#
# n_hospitals          = 9
# n_hospitals_50%_occup = 9
# max_satisf_index     = 9.3
# min_satisf_index     = 1.1
# total_beds           = 4409
# mean_satisf_index    = 4.3
# ________________________________________________________________________________
#
# ________________________________Region de Murcia________________________________
#
# n_hospitals          = 6
# n_hospitals_50%_occup = 6
# max_satisf_index     = 9.4
# min_satisf_index     = 1.9
# total_beds           = 3790
# mean_satisf_index    = 4.9
# ________________________________________________________________________________
#
# ____________________________________Navarra_____________________________________
#
# n_hospitals          = 4
# n_hospitals_50%_occup = 4
# max_satisf_index     = 9.0
# min_satisf_index     = 6.8
# total_beds           = 2617
# mean_satisf_index    = 7.8
# ________________________________________________________________________________
#
# ___________________________________Pais Vasco___________________________________
#
# n_hospitals          = 11
# n_hospitals_50%_occup = 11
# max_satisf_index     = 9.3
# min_satisf_index     = 1.6
# total_beds           = 6689
# mean_satisf_index    = 6.2
# ________________________________________________________________________________
#
# ____________________________________La Rioja____________________________________
#
# n_hospitals          = 3
# n_hospitals_50%_occup = 3
# max_satisf_index     = 3.6
# min_satisf_index     = 2.3
# total_beds           = 1587
# mean_satisf_index    = 3.1
# ________________________________________________________________________________
#
# _____________________________________Ceuta______________________________________
#
# n_hospitals          = 1
# n_hospitals_50%_occup = 1
# max_satisf_index     = 6.3
# min_satisf_index     = 6.3
# total_beds           = 208
# mean_satisf_index    = 6.3
# ________________________________________________________________________________
#
# ____________________________________Melilla_____________________________________
#
# n_hospitals          = 1
# n_hospitals_50%_occup = 1
# max_satisf_index     = 6.5
# min_satisf_index     = 6.5
# total_beds           = 652
# mean_satisf_index    = 6.5
# ________________________________________________________________________________
