# %% [markdown]
# Copiamos la base de datos y comenzamos la limpieza

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from datetime import datetime, date, time, timedelta
from getpass import getpass
from sqlalchemy import create_engine, inspect

# %%
puerto = "3306"
user="Equipo33"
password="E1q2u3i4p5o33"
database="Equip_33"

engine = create_engine(f"mysql+mysqlconnector://{user}:{password}@212.227.148.202:{puerto}/{database}")

inspector = inspect(engine)

tablas = inspector.get_table_names()

for nombre in tablas: 
    globals()[f"df_{nombre}"] = pd.read_sql_query(f"SELECT * FROM {nombre}", engine)

# %%
df_RRHH
# Out:
#      ID  Reason_absence  Month_absence  Day_week  Seasons  \
# 0    14              11             11         2        4
# 1    36              13              4         4        3
# 2     9               6              7         3        1
# 3    28               9              7         3        1
# 4     9              12              3         3        2
# ..   ..             ...            ...       ...      ...
# 735   2               0              6         2        3
# 736  21               0              6         2        3
# 737   4               0              0         3        1
# 738   8               0              0         4        2
# 739  35               0              0         6        3
#
#      Transportation_expense  Distance_Residence_Work  Service_time  Age  \
# 0                       155                       12            14   34
# 1                       118                       13            18   50
# ...

# %%
# Quitamos los duplicados exactos 

# Ver cuántos duplicados exactos hay
duplicados_exactos = df_RRHH.duplicated().sum()
print("Duplicados exactos:", duplicados_exactos)

df_RRHH = df_RRHH.drop_duplicates()

# Reiniciar el índice
df_RRHH = df_RRHH.reset_index(drop=True)

print("Filas después de eliminar duplicados:", df_RRHH.shape[0])
# Out:
# Duplicados exactos: 34
# Filas después de eliminar duplicados: 706

# %%
# Pasar columnas de códigos a int

cols_codigos = ["Day_week", "Education", "Seasons", "Reason_absence"]

df_RRHH[cols_codigos] = df_RRHH[cols_codigos].astype(int)

# %%
# ==============================
# MAPAS DE SIGNIFICADO
# ==============================

day_week_map = {
    2: "Lunes",
    3: "Martes",
    4: "Miércoles",
    5: "Jueves",
    6: "Viernes"}

education_map = {
    1: "Educación secundaria",
    2: "Graduado",
    3: "Postgrado",
    4: "Máster o doctorado"}

seasons_map = {
    1: "Verano",
    2: "Otoño",
    3: "Invierno",
    4: "Primavera"}

reason_absence_map = {
    0: "Sin ausencia registrada",
    1: "Enfermedades infecciosas y parasitarias",
    2: "Neoplasias (tumores)",
    3: "Enfermedades de la sangre y del sistema inmunitario",
    4: "Enfermedades endocrinas, nutricionales y metabólicas",
    5: "Trastornos mentales y del comportamiento",
    6: "Enfermedades del sistema nervioso",
    7: "Enfermedades del ojo",
    8: "Enfermedades del oído",
    9: "Enfermedades del sistema circulatorio",
    10: "Enfermedades del sistema respiratorio",
    11: "Enfermedades del sistema digestivo",
    12: "Enfermedades de la piel",
    13: "Enfermedades del sistema musculoesquelético",
    14: "Enfermedades del sistema genito-urinario",
    15: "Embarazo, parto y puerperio",
    16: "Afecciones del periodo perinatal",
    17: "Malformaciones congénitas",
    18: "Síntomas y hallazgos clínicos no clasificados",
    19: "Lesiones y envenenamientos",
    20: "Causas externas de morbilidad",
    21: "Factores que influyen en el estado de salud",
    22: "Seguimiento de paciente",
    23: "Consulta médica",
    24: "Donación de sangre",
    25: "Examen de laboratorio",
    26: "Ausencia injustificada",
    27: "Fisioterapia",
    28: "Consulta dental"}

# ==============================
# CREAR COLUMNAS DESCRIPTIVAS
# ==============================

df_RRHH = df_RRHH.assign(
    Day_week_desc=df_RRHH["Day_week"].map(day_week_map),
    Education_desc=df_RRHH["Education"].map(education_map),
    Season_desc=df_RRHH["Seasons"].map(seasons_map),
    Reason_absence_desc=df_RRHH["Reason_absence"].map(reason_absence_map))

# ==============================
# COMPROBACIÓN DE VALORES SIN MAPEAR
# ==============================

cols_check = [
    ("Day_week", "Day_week_desc"),
    ("Education", "Education_desc"),
    ("Seasons", "Season_desc"),
    ("Reason_absence", "Reason_absence_desc")]

for col_codigo, col_desc in cols_check:
    valores_sin_mapear = df_RRHH.loc[df_RRHH[col_desc].isna(), col_codigo].unique()
    
    if len(valores_sin_mapear) > 0:
        print(f"Valores sin mapear en {col_codigo}: {valores_sin_mapear}")
    else:
        print(f"{col_codigo}: todos los valores están correctamente mapeados")
# Out:
# Day_week: todos los valores están correctamente mapeados
# Education: todos los valores están correctamente mapeados
# Seasons: todos los valores están correctamente mapeados
# Reason_absence: todos los valores están correctamente mapeados

# %%
df_RRHH
# Out:
#      ID  Reason_absence  Month_absence  Day_week  Seasons  \
# 0    14              11             11         2        4
# 1    36              13              4         4        3
# 2     9               6              7         3        1
# 3    28               9              7         3        1
# 4     9              12              3         3        2
# ..   ..             ...            ...       ...      ...
# 701   2               0              6         2        3
# 702  21               0              6         2        3
# 703   4               0              0         3        1
# 704   8               0              0         4        2
# 705  35               0              0         6        3
#
#      Transportation_expense  Distance_Residence_Work  Service_time  Age  \
# 0                       155                       12            14   34
# 1                       118                       13            18   50
# ...

# %%
# Reordenar columnas para poner cada columna descriptiva al lado de su código

columnas = list(df_RRHH.columns)

pares = {
    "Day_week": "Day_week_desc",
    "Education": "Education_desc",
    "Seasons": "Season_desc",
    "Reason_absence": "Reason_absence_desc"
}

nuevo_orden = []

for col in columnas:
    if col in pares:
        nuevo_orden.append(col)
        nuevo_orden.append(pares[col])
    elif col not in pares.values():
        nuevo_orden.append(col)

df_RRHH = df_RRHH[nuevo_orden]
df_RRHH
# Out:
#      ID  Reason_absence                          Reason_absence_desc  \
# 0    14              11           Enfermedades del sistema digestivo
# 1    36              13  Enfermedades del sistema musculoesquelético
# 2     9               6            Enfermedades del sistema nervioso
# 3    28               9        Enfermedades del sistema circulatorio
# 4     9              12                      Enfermedades de la piel
# ..   ..             ...                                          ...
# 701   2               0                      Sin ausencia registrada
# 702  21               0                      Sin ausencia registrada
# 703   4               0                      Sin ausencia registrada
# 704   8               0                      Sin ausencia registrada
# 705  35               0                      Sin ausencia registrada
#
#      Month_absence  Day_week Day_week_desc  Seasons Season_desc  \
# 0               11         2         Lunes        4   Primavera
# ...

# %%
df_RRHH = df_RRHH.reset_index().rename(columns={"index": "ID_Absence"})

# Renombrar columnas de df_RRHH para que coincidan con la tabla MySQL RRHH_CLEAN

df_RRHH = df_RRHH.rename(columns={
    "Unnamed: 0": "ID_Absence",
    "ID": "ID_Employee",

    "Reason_absence": "Reason_Absence",
    "Reason_absence_desc": "Reason_Absence_Desc",
    "Reason_absence_Desc": "Reason_Absence_Desc",
    "Reason_Absence_desc": "Reason_Absence_Desc",

    "Month_absence": "Month_Absence",

    "Day_week": "Day_Week",
    "Day_week_desc": "Day_Week_Desc",
    "Day_Week_desc": "Day_Week_Desc",

    "Seasons": "Seasons",
    "Season_desc": "Season_Desc",
    "Seasons_desc": "Season_Desc",

    "Transportation_expense": "Transportation_Expense",
    "Distance_Residence_Work": "Distance_Residence_Work",
    "Service_time": "Service_Time",
    "Age": "Age",

    "Work_load_Average_day": "Work_load_Average_Day",

    "Hit_target": "Hit_Target",
    "Disciplinary_failure": "Disciplinary_Failure",

    "Education": "Education",
    "Education_desc": "Education_Desc",

    "Son": "Son",
    "Social_drinker": "Social_Drinker",
    "Social_smoker": "Social_Smoker",
    "Pet": "Pet",
    "Weight": "Weight",
    "Height": "Height",

    "Body_mass_index": "Body_Mass_Index",
    "Body_Dass_Index": "Body_Mass_Index",

    "Absenteeism_time_in_hours": "Absenteeism_Hours",
    "Absenteeism_hours": "Absenteeism_Hours"
})

df_RRHH.columns
# Out:
# Index(['ID_Absence', 'ID_Employee', 'Reason_Absence', 'Reason_Absence_Desc',
#        'Month_Absence', 'Day_Week', 'Day_Week_Desc', 'Seasons', 'Season_Desc',
#        'Transportation_Expense', 'Distance_Residence_Work', 'Service_Time',
#        'Age', 'Work_load_Average_Day', 'Hit_Target', 'Disciplinary_Failure',
#        'Education', 'Education_Desc', 'Son', 'Social_Drinker', 'Social_Smoker',
#        'Pet', 'Weight', 'Height', 'Body_Mass_Index', 'Absenteeism_Hours'],
#       dtype='object')

# %%
# Cambiamos dtypes

df_RRHH["Transportation_Expense"] = df_RRHH["Transportation_Expense"].astype(float)

df_RRHH["Work_load_Average_Day"] = (
    df_RRHH["Work_load_Average_Day"]
    .astype(str)
    .str.replace(",", ".", regex=False)
    .astype(float)
)

cols_a_int = [
    "Disciplinary_Failure",
    "Son",
    "Social_Drinker",
    "Social_Smoker",
    "Pet"
]

df_RRHH[cols_a_int] = df_RRHH[cols_a_int].astype(int)

df_RRHH.dtypes
# Out:
# ID_Absence                   int64
# ID_Employee                  int64
# Reason_Absence               int64
# Reason_Absence_Desc         object
# Month_Absence                int64
# Day_Week                     int64
# Day_Week_Desc               object
# Seasons                      int64
# Season_Desc                 object
# Transportation_Expense     float64
# Distance_Residence_Work      int64
# Service_Time                 int64
# Age                          int64
# Work_load_Average_Day      float64
# Hit_Target                   int64
# Disciplinary_Failure         int64
# Education                    int64
# Education_Desc              object
# Son                          int64
# Social_Drinker               int64
# Social_Smoker                int64
# Pet                          int64
# Weight                       int64
# Height                       int64
# Body_Mass_Index              int64
# Absenteeism_Hours            int64
# dtype: object

# %%
df_RRHH["ID_Employee"].unique()
# Out:
# array([14, 36,  9, 28, 11, 13, 34, 22, 26, 20, 10, 15, 17, 24,  3, 18,  7,
#         1, 30,  5,  6,  2, 31, 27, 33, 23, 21, 25, 12, 32, 16, 29, 19,  8,
#         4, 35])

# %%
df_RRHH[df_RRHH["ID_Employee"]==29]
# Out:
#      ID_Absence  ID_Employee  Reason_Absence  \
# 251         251           29              14
# 252         252           29              22
# 430         430           29              19
# 536         536           29              28
# 664         664           29               0
#
#                           Reason_Absence_Desc  Month_Absence  Day_Week  \
# 251  Enfermedades del sistema genito-urinario              5         5
# 252                   Seguimiento de paciente              5         6
# 430                Lesiones y envenenamientos              5         4
# 536                           Consulta dental              2         6
# 664                   Sin ausencia registrada              9         2
#
#     Day_Week_Desc  Seasons Season_Desc  Transportation_Expense  ...  \
# 251        Jueves        3    Invierno                   225.0  ...
# 252       Viernes        3    Invierno                   225.0  ...
# ...

# %%
# Eliminamos el registro 698 del ID_Employe 29 ya que hay incongruencias en los datos personales del empleado

df_RRHH = df_RRHH[df_RRHH["ID_Absence"] != 664].reset_index(drop=True)

df_RRHH
# Out:
#      ID_Absence  ID_Employee  Reason_Absence  \
# 0             0           14              11
# 1             1           36              13
# 2             2            9               6
# 3             3           28               9
# 4             4            9              12
# ..          ...          ...             ...
# 700         701            2               0
# 701         702           21               0
# 702         703            4               0
# 703         704            8               0
# 704         705           35               0
#
#                              Reason_Absence_Desc  Month_Absence  Day_Week  \
# 0             Enfermedades del sistema digestivo             11         2
# 1    Enfermedades del sistema musculoesquelético              4         4
# 2              Enfermedades del sistema nervioso              7         3
# 3          Enfermedades del sistema circulatorio              7         3
# ...

# %%
df_RRHH[df_RRHH["ID_Employee"]==29]
# Out:
#      ID_Absence  ID_Employee  Reason_Absence  \
# 251         251           29              14
# 252         252           29              22
# 430         430           29              19
# 536         536           29              28
#
#                           Reason_Absence_Desc  Month_Absence  Day_Week  \
# 251  Enfermedades del sistema genito-urinario              5         5
# 252                   Seguimiento de paciente              5         6
# 430                Lesiones y envenenamientos              5         4
# 536                           Consulta dental              2         6
#
#     Day_Week_Desc  Seasons Season_Desc  Transportation_Expense  ...  \
# 251        Jueves        3    Invierno                   225.0  ...
# 252       Viernes        3    Invierno                   225.0  ...
# 430     Miércoles        3    Invierno                   225.0  ...
# 536       Viernes        2       Otoño                   225.0  ...
#
# ...

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# ==============================
# Conexión MySQL
# ==============================


usuario = "Equipo33"
password = quote_plus("E1q2u3i4p5o33")
host = "212.227.148.202"
puerto = "3306"
base_datos = "Equip_33"

engine = create_engine(
    f"mysql+pymysql://{usuario}:{password}@{host}:{puerto}/{base_datos}?charset=utf8mb4"
)

# ==============================
# Insertar dataframe en MySQL
# ==============================

df_RRHH.to_sql(
    name="RRHH_CLEAN",
    con=engine,
    if_exists="append",
    index=False,
    chunksize=1000,
    method="multi"
)

print("Datos insertados correctamente en MySQL")
# Out:
# Datos insertados correctamente en MySQL

# %%
df_RRHH.to_csv("df_RRHH.csv")
