# %% [markdown]
# <a href="https://colab.research.google.com/github/raulmabcn/DataAnalyst/blob/main/Bloque4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Detecta comunidades autónomas donde:
#   El crecimiento de pacientes (respecto a la media nacional) es alto pero el crecimiento de camas no lo es. (Define tú la métrica de crecimiento).
#
# Identifica hospitales atípicos usando:
# * Z-score sobre indice_satisfaccion
# * IQR
#
# Simula un escenario donde:
# * aumentan los pacientes un 15%
# * disminuyen los médicos un 10%
# ¿Qué hospitales pasarían a estar en situación crítica (ocupación > 90%)?
#
# Construye una tabla resumen final por comunidad autónoma con:
# * total hospitales
# * total camas
# * total pacientes
# * ocupación media
# * satisfacción media
# * ratio pacientes/cama
# * ratio pacientes/médico
#
# Ordena por eficiencia (define tú eficiencia).
