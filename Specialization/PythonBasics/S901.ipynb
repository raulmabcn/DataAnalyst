# %% [markdown]
# <a href="https://colab.research.google.com/github/raulmabcn/DataAnalyst/blob/main/Specialization/PythonBasics/S901.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nivel1
# ## Calculadora de l'índex de massa corporal
#
# Escriu una funció que calculi l'IMC ingressat per l'usuari/ària, és a dir, qui ho executi haurà d'ingressar aquestes dades.
#
# La funció ha de classificar el resultat en les seves respectives categories.
#
# Consell: Intenta validar les dades prèviament, perquè enviï un missatge d’advertència si les dades introduïdes per l’usuari/a no estan en el format adequat o no pren valors raonables.

# %%
def request_correct_data( data_error ):

  user_input = {}
  message = {
      'kg': 'Introduce de nuevo tu peso en kg, siguiendo el formato (ej 80.3): ',
      'hg': 'Introduce de nuevo tu altura en metros, siguiendo el formato (ej 1.80) : '
  }

  print( f"Parece que hay un error en tus datos de entrada: { list( data_error.values() ) }\n" )

  for key,error in data_error.items():
    user_input[key] = input( f"{message[key]}" )

  return user_input

def convert_to_float(user_input):

  user_data   = {}
  data_error  = {}

  for data in user_input.keys():
    try:
      user_data[data] = float(user_input[data])

    except ValueError:
      data_error[data] = user_input[data]

  return user_data, data_error


def check_range_values( input, data_error ):

  check_data = {}
  range_values = { 'kg': [0,300], 'm': [0,3] }

  for key, value in input.items():
    if value <= range_values[key][0] or value >= range_values[key][1]:
      data_error[key]   = value
    else
      check_data[key]   = value

  return check_data, data_error


def check_data_values( user_input ):

  check_data = {}

  converted_input, data_error = convert_to_float( user_input )

  if converted_input:
    check_data, data_error = check_range_values( converted_input, data_error )

  return check_data, data_error



def get_filtered_data( user_input ):

  data_filtered, data_error = check_data_values( user_input )

  while data_error:
    user_input = request_correct_data( data_error )
    data_filtered_tmp, data_error = check_data_values( user_input )
    data_filtered.update( data_filtered_tmp )

  return data_filtered


def get_imc_range( user_imc ):

  if user_imc < 18.5:
    range = 'Bajo peso'
  elif user_imc < 25:
    range = 'Peso normal'
  elif user_imc < 30:
    range = 'Sobrepeso'
  else:
    range = 'Obesidad'

  return range


def print_message( user_data,user_imc ):

  kg    = user_data['kg']
  hg    = user_data['hg']
  range = get_imc_range( user_imc )

  print(f"Con tu peso {kg} kg y altura {hg} m,\ntu imc es: {user_imc}, el cual se considera {range}")


def calculate_imc( user_data):

  return round( user_data['kg'] / pow( user_data['hg'], 2), 2 )


def request_data():

  user_input = {}
  user_input['kg'] = input("Introduce tu peso en kg,  75.5: ")
  user_input['hg'] = input("\nIntroduce tu altura en metros, 1.75: ")

  return user_input


def main():

  print("Calculadora de indice de masa corporal\n")

  user_input  = request_data()
  user_data   = get_filtered_data( user_input )
  user_imc    = calculate_imc( user_data )

  print_message( user_data, user_imc )


main()
# Out:
# Calculadora de indice de masa corporal
#
# Introduce tu peso en kg,  75.5: safsd
#
# Introduce tu altura en metros, 1.75: asdfasdf
# Parece que hay un error en tus datos de entrada: [('kg', 'safsd'), ('hg', 'asdfasdf')]
#
# Introduce de nuevo tu peso en kg, siguiendo el formato (ej 80.3): 60,3
# Introduce de nuevo tu altura en metros, siguiendo el formato (ej 180.3) : 1.75
# Parece que hay un error en tus datos de entrada: [('kg', '60,3')]
#
# Introduce de nuevo tu peso en kg, siguiendo el formato (ej 80.3): 60.3
# Con tu peso 60.3 kg y altura 1.75 m,
# tu imc es: 19.69, el cual se considera Peso normal

# %% [markdown]
# ## Convertidor de temperatures
#
# Existeixen diverses unitats de temperatura utilitzades en diferents contextos i regions. Les més comunes són Celsius (°C), Fahrenheit (°F) i Kelvin (K). També existeixen altres unitats com Rankine (°Ra) i Réaumur (°Re).
#
# Selecciona almenys 2 conversors, de tal manera que en introduir una temperatura retorni, com a mínim, dues conversions, de manera que es puguin guardar (recorda que un print() no es pot guardar mai).
#
# Consell: Intenta validar les dades prèviament, perquè enviï un missatge d’advertència si les dades introduides per l’usuari/a no estan en el format adequat.
#
# (EXTRA): Pensa una manera d’emmagatzemar totes les possibles conversions en un sol objecte (Llista? Diccionari? DataFrame?) en comptes d’escriure molts if else en funció de la temperatura d’origen i la temperatura de destí.

# %%
celcious_convertions = {
    'F'  : lambda x: (x * 1.8) + 32,
}

fahrenheit_convertions = {
    'C'  : lambda x: (x - 32)/1.8,
}

min_values = {
    'C'  : -273.15,
    'F'  : -459.67
}


unit_acronym = {
    'C'  : 'Celcius',
    'F'  : 'Fahrenheit'
}

list_convertions = {
    'C': ['F'],
    'F': ['C']
}


def convert_to_float( user_input ):

  try:
      data = float( user_input)
  except ValueError:
      data = False

  return data

def check_range_value( user_input, unit_origin ):

  if user_input >= min_values[unit_origin]
      data  = user_input
  else
      data  = False

  return data


def request_value( unit_origin ):

  return input("Introduce la temperatura a convertir (ej 34.6):")


def check_value( value, unit_origin ):

    value = convert_to_float( value )

    if not value:
      print("Error float")
    else:
      value = check_range_value( value, unit_origin )
      if not value:
        print("Error rango")

    return value

def check_unit( unit, destiny = False ):

  if not destiny:
    if list_convertions.get( unit ) is None:
      unit = False
  else
    if destiny not in list_convertions.get( unit )
      unit = False

  return unit

def request_unit_destiny( unit_origin ):

  print("Elige la unidad de destino de entre las de la lista introduciendo sus siglas.")
  [print( f"{ unit_acronym[value]} ({value}) " ) for value in list_convertions[unit_origin]]

  unit_destiny = input("\n")

  return unit_destiny



def request_unit_origin():

  print("Elige la unidad de origen de entre las de la lista introduciendo sus siglas.")
  [print( f"{value} ({key}) " ) for key,value in unit_acronym.items()]


  unit_origin = input("\n")

  return unit_origin



def request_data():

  origin_unit = False
  while not origin_unit
    user_unit     = request_unit_origin()
    origin_unit   = check_unit( user_unit )

  data_value = False
  while not data_value
    user_value    = request_value()
    data_value    = check_value( user_value, origin_unit )

  destiny_unit = False
  while not destiny_unit
    user_destiny  = request_unit_destiny( origin_unit )
    destiny_unit  = check_unit( user_unit, user_destiny )



request_data()
# Out:
# Elige la unidad de origen de entre las de la lista introduciendo sus siglas.
# Celcius (C)
# Fahrenheit (F)
# Remain (Re)
#
# C
# Elige la unidad de destino de entre las de la lista introduciendo sus siglas.
# Fahrenheit (F)
# Remain (Re)
#
# Re

# %% [markdown]
# celcious_convertions = {
#     'F'  : lambda x: (x * 1.8) + 32,
#     'K'  : lambda x: x + 273.15,
#     'Ra' : lambda x: (x * 1.8) + 491.67,
#     'Re' : lambda x: x * 0.8
# }
#
# fahrenheit_convertions = {
#     'C'  : lambda x: (x - 32)/1.8,
#     'K'  : lambda x: (x - 32) * 5/9 + 273.15,
#     'Ra' : lambda x: x + 459.67,
#     'Re' : lambda x: (x - 32)/2.25
# }
#
# kelvin_convertions = {
#     'C'  : lambda x: x - 273.15,
#     'F'  : lambda x: (x - 273.15) * 1.8 + 32,
#     'Ra' : lambda x: x * 1.8,
#     'Re' : lambda x: (x - 273.15) * 0.8
# }
#
# rankine_convertions = {
#     'C'  : lambda x: (x - 491.67)/1.8,
#     'F'  : lambda x: x - 459.67,
#     'K'  : lambda x: x/1.8,
#     'Re' : lambda x: (x - 491.67)/2.25
# }
#
# reamur_convertions = {
#     'C'  : lambda x: x * 1.25,
#     'F'  : lambda x: (x * 2.25) + 32,
#     'K'  : lambda x: (x * 1.25) + 273.15,
#     'Ra' : lambda x: (x * 2.25) + 491.67
# }
#
# min_values = {
#     'C'  : -273.15,
#     'F'  : -459.67,
#     'K'  : 0,
#     'Ra' : 0,
#     'Re' : -218.52
# }
